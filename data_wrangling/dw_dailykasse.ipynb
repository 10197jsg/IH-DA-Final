# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Daily Kasse excel

# %%
dk23 = pd.concat(pd.read_excel("../data_files/mm_dk_2023.xlsx", sheet_name=None))

# %%
dk24 = pd.concat(pd.read_excel("./data_files/mm_dk_2024.xlsx", sheet_name=None))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dk24 = pd.concat(pd.read_excel("./data_files/mm_dk_2024.xlsx", sheet_name=None))
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...

# %%
dk25 = pd.concat(pd.read_excel("./data_files/mm_dk_2025.xlsx", sheet_name=None))

# %%
dk = pd.concat([dk23, dk24, dk25])
dk
# Out:
#                 DATE TIME    CASH     CARD UBER  WOLT   TOTAL    TIPS  EXP #1  \
# 2023-1 0  2023-01-01  NaN     NaN      NaN  NaN   NaN     0.0     NaN     NaN
#        1  2023-01-02  NaN     NaN      NaN  NaN   NaN     0.0     NaN     NaN
#        2  2023-01-03    d  139.00  1047.00  NaN   NaN  1186.0   42.10    2.07
#        3  2023-01-04    d  324.00   537.50  NaN   NaN   861.5   22.50   30.00
#        4  2023-01-05    d  173.50  1105.10  NaN   NaN  1278.6   67.60     NaN
# ...              ...  ...     ...      ...  ...   ...     ...     ...     ...
# 2025-5 36 2025-05-29    n  159.90  2375.00  0.0   0.0  2534.9     NaN     NaN
#        37 2025-05-30    d  154.80  1428.40  0.0  61.5  1644.7  138.94     NaN
#        38 2025-05-30    n  103.00  1643.00  0.0   0.0  1746.0  156.31   33.00
#        39 2025-05-31    d   45.90  1763.10  0.0  53.3  1862.3  179.11     NaN
#        40 2025-05-31    n  457.27  2314.13  0.0   0.0  2771.4  226.88     NaN
#
# ...

# %%
dk.columns
# Out:
# Index(['DATE', 'TIME', 'CASH', 'CARD', 'UBER', 'WOLT', 'TOTAL', 'TIPS',
#        'EXP #1', 'EXP #2', 'EXP #3', 'CASH TO DEPOSIT', 'NAME',
#        'Daily Notes (__PLEASE FILL UP_ IMPORTANT FOR STATISTICS LATER)'],
#       dtype='object')

# %%
dk.isnull()
# Out:
#             DATE   TIME   CASH   CARD   UBER   WOLT  TOTAL   TIPS  EXP #1  \
# 2023-1 0   False   True   True   True   True   True  False   True    True
#        1   False   True   True   True   True   True  False   True    True
#        2   False  False  False  False   True   True  False  False   False
#        3   False  False  False  False   True   True  False  False   False
#        4   False  False  False  False   True   True  False  False    True
# ...          ...    ...    ...    ...    ...    ...    ...    ...     ...
# 2025-5 36  False  False  False  False  False  False  False   True    True
#        37  False  False  False  False  False  False  False  False    True
#        38  False  False  False  False  False  False  False  False   False
#        39  False  False  False  False  False  False  False  False    True
#        40  False  False  False  False  False  False  False  False    True
#
#            EXP #2  EXP #3  CASH TO DEPOSIT   NAME  \
# ...

# %%
dk.isna().any()
# Out:
# DATE                                                               True
# TIME                                                               True
# CASH                                                               True
# CARD                                                               True
# UBER                                                               True
# WOLT                                                               True
# TOTAL                                                             False
# TIPS                                                               True
# EXP #1                                                             True
# EXP #2                                                             True
# EXP #3                                                             True
# CASH TO DEPOSIT                                                    True
# NAME                                                               True
# ...

# %%
dk.isna().sum()
# Out:
# DATE                                                                1
# TIME                                                              186
# CASH                                                              186
# CARD                                                              189
# UBER                                                              533
# WOLT                                                              523
# TOTAL                                                               0
# TIPS                                                              190
# EXP #1                                                            642
# EXP #2                                                            902
# EXP #3                                                            963
# CASH TO DEPOSIT                                                     1
# NAME                                                              861
# ...

# %%
dk.isna().sum(axis=1)
# Out:
# 2023-1  0     11
#         1     11
#         2      6
#         3      6
#         4      7
#               ..
# 2025-5  36     4
#         37     3
#         38     2
#         39     3
#         40     3
# Length: 971, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(dk.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
dk.to_excel('./data_files/dk.xlsx', index=False)
